# %% [markdown]
# # Object Oriented Programming and File I/O

# %%
class Person:
    pass

student = Person()
student.name = "Sadiya"
student.company = "Airobosoft"
student.year_of_join = 2020


print(student)
print("%s joined %s  in %d." %
      (student.name, student.company, student.year_of_join))
# Out:
# <__main__.Person object at 0x0000012CC95E4748>
# Sadiya joined Airobosoft  in 2020.

# %%
class Place:
    def __init__(company, name, city , year_of_start):
        company.name = name
        company.city = city
        company.year_of_start = year_of_start

# %%
airobosoft = Place("Airobosoft", "Bangalore", 2020)
print(airobosoft)
print("%s is company in %s which started in the year %d"% (airobosoft.name,airobosoft.city,airobosoft.year_of_start))
# Out:
# <__main__.Place object at 0x0000012CC9609488>
# Airobosoft is company in Bangalore which started in the year 2020

# %%
class Info:
    def __init__(self , name , field , place , year_of_start):
        self.name = name
        self.field = field
        self.place = place
        self.year_of_start = year_of_start
    
    def years(self , year_of_complete):
        return year_of_complete - self.year_of_start
    
    def __str__(self):
        return "%s studied %s in %s in the year %d ."%(self.name , self.field , self.place , self.year_of_start)
    
ruby = Info("Ruby","medicine","mangalore",2013)
print(ruby)
print(ruby.years(2018))
# Out:
# Ruby studied medicine in mangalore in the year 2013 .
# 5

# %%
class Person:
    def __init__(self, name, surname, year_of_birth):
        self.name = name
        self.surname = surname
        self.year_of_birth = year_of_birth
    
    def age(self, current_year):
        return current_year - self.year_of_birth
    
    def __str__(self):
        return "%s %s was born in %d ." % (self.name, self.surname, self.year_of_birth)
    
ruby = Person("Ruby", "sheikh", 2001)
print(ruby)
print(ruby.age(2019))

class Student(Person):
    def __init__(self, student_id, *args, **kwargs):
        super(Student, self).__init__(*args, **kwargs)
        self._student_id = student_id
        
ruby = Student(3, 'Ruby', 'Shiekh',2001 )
print(ruby)
print(type(ruby))
print(isinstance(ruby, Person))
print(isinstance(ruby, object))
# Out:
# Ruby sheikh was born in 2001 .
# 18
# Ruby Shiekh was born in 2001 .
# <class '__main__.Student'>
# True
# True

# %%
class Student(Person):
    def __init__(self, student_id, *args, **kwargs):
        super(Student, self).__init__(*args, **kwargs)
        self._student_id = student_id
        
    def __str__(self):
        return super(Student, self).__str__() + " And has Student ID: %d" % self._student_id
        
Ruby = Student(3, 'Ruby', 'Sheikh', 2001)
print(Ruby)
# Out:
# Ruby Sheikh was born in 2001 . And has Student ID: 3

# %%
def rainy(a, b , c):
    return a + b + c

print(rainy(1, 2 , 3))
print(rainy(["rain", "water"], ["thunder"] ,["lighting"]))
print(rainy("rainy", "season","...."))
# Out:
# 6
# ['rain', 'water', 'thunder', 'lighting']
# rainyseason....

# %%
# %%writefile great.text
# Allah is great..
# Out:
# Overwriting great.text

# %%
# Open the text.txt we made earlier
my_file = open('great.text')

# %%
# We can now read the file
my_file.read()
# Out:
# 'Allah is great..\n'

# %%
# But what happens if we try to read it again?
my_file.read()
# Out:
# ''

# %%
# Seek to the start of file (index 0)
my_file.seek(0)
# Out:
# 0

# %%
# Now read again
my_file.read()
# Out:
# 'Allah is great..\n'

# %%
# Seek to the start of file (index 0)
my_file.seek(0)
# Out:
# 0

# %%
# Readlines returns a list of the lines in the file.
my_file.readlines()
# Out:
# ['Allah is great..\n']

# %%
# Add the second argument to the function, 'w' which stands for write
my_file = open('great.text','w+')

# %%
# Write to the file
my_file.write('Allah is great')
# Out:
# 14

# %%
# Seek to the start of file 
my_file.seek(0)
# Out:
# 0

# %%
# Read the file
my_file.read()
# Out:
# 'Allah is great'

# %%
# %%writefile info.txt
# Airobosoft
# bangalore
# Out:
# Overwriting info.txt

# %%
for line in open('info.txt'):
    print(line)
# Out:
# Airobosoft
#
# bangalore

# %%
# Pertaining to the first point above
for company in open('info.txt'):
    print(company)
# Out:
# Airobosoft
#
# bangalore

# %%
from io import StringIO

# %%
# Arbitrary String
message = 'Airobosoft is a intillegence company in bangalore.'

# %%
# Use StringIO method to set as file object
f = StringIO(message)

# %%
f.read()
# Out:
# 'Airobosoft is a intillegence company in bangalore.'

# %%
f.write(' It gives intership to students')
# Out:
# 31

# %%
# Reset cursor just like you would a file
f.seek(1)
# Out:
# 1

# %%
# Read again
f.read()
# Out:
# 'irobosoft is a intillegence company in bangalore. It gives intership to students'
